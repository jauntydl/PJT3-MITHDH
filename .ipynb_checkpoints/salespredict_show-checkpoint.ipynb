# %%
import datetime as dt
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import json

from sklearn.metrics import mean_squared_error
from matplotlib import pyplot as plt

from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras.layers import LSTM
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.preprocessing import MinMaxScaler

datapath = 'resources/globalsales.csv'
# Out:
# Using TensorFlow backend.

# %%
       
def to_json(datapath, year = 2021, output = 'sales'):
    
    cats = ["Furniture", "Office Supplies", "Technology"]
    subcats = [["Bookcases", "Furnishings", "Tables", "Chairs"],["Appliances", "Binders", "Envelopes", "Fasteners", "Labels", "Paper", "Storage", "Supplies", "Art"],["Accessories", "Machines", "Phones", "Copiers"]]
    markets = ["Africa", "Asia Pacific", "Europe", "LATAM", "USCA"]
    regions = [["Central Africa", "Eastern Africa", "North Africa", "Southern Africa", "Western Africa"],["Central Asia", "Eastern Asia", "Oceania", "Southeastern Asia", "Southern Asia", "Western Asia"],["Eastern Europe", "Northern Europe", "Southern Europe", "Western Europe"],["Caribbean", "Central America", "South America"],["Canada", "Central US", "Eastern US", "Southern US", "Western US"]]
    
    
    data =[]
    n1=0
    alls = 'all'
    for cat in cats:
        d={}
        d["cat"] = cat
        d["subcat"] = alls
        d["market"] = alls
        d["region"] = alls
        data.append(d)

        subcat_u = subcats[n1]
        n1 = n1 + 1
        for subcat in subcat_u:
            d={}
            d["cat"] = cat
            d["subcat"] = subcat
            d["market"] = alls
            d["region"] = alls
            data.append(d)
            n2 = 0
            for market in markets:
                d={}
                d["cat"] = cat
                d["subcat"] = subcat
                d["market"] = market
                d["region"] = alls
                data.append(d)
                
                region_u = regions[n2]
                n2 = n2 + 1
                for region in region_u:
                    d ={}
                    d["cat"] = cat
                    d["subcat"] = subcat
                    d["market"] = market
                    d["region"] = region
                    
                    try:
                        d["x"], d["y"] ,d["y_fcst"] ,d["MSE"], d["MAPE"] = return_forecast(datapath, year = year, output = output, cat = cat, subcat = subcat, market = market, region = region)
                    except Exception:
                        pass

                    data.append(d)
    
    return data

# %%
cats = ["all","Furniture", "Office Supplies", "Technology"]
subcats = [["all","Bookcases", "Furnishings", "Tables", "Chairs"],["all","Appliances", "Binders", "Envelopes", "Fasteners", "Labels", "Paper", "Storage", "Supplies", "Art"],["all","Accessories", "Machines", "Phones", "Copiers"]]
markets = ["all","Africa", "Asia Pacific", "Europe", "LATAM", "USCA"]
regions = [["all","Central Africa", "Eastern Africa", "North Africa", "Southern Africa", "Western Africa"],["all","Central Asia", "Eastern Asia", "Oceania", "Southeastern Asia", "Southern Asia", "Western Asia"],["all","Eastern Europe", "Northern Europe", "Southern Europe", "Western Europe"],["all","Caribbean", "Central America", "South America"],["all","Canada", "Central US", "Eastern US", "Southern US", "Western US"]]
    
regions[4]
# Out:
# ['all', 'Canada', 'Central US', 'Eastern US', 'Southern US', 'Western US']

# %%
test = to_json(datapath)

test
# Out:
# [{'cat': 'Furniture', 'subcat': 'all', 'market': 'all', 'region': 'all'},
#  {'cat': 'Furniture', 'subcat': 'Bookcases', 'market': 'all', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Bookcases',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Furnishings',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Furniture', 'subcat': 'Tables', 'market': 'all', 'region': 'all'},
#  {'cat': 'Furniture', 'subcat': 'Tables', 'market': 'Africa', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Furniture', 'subcat': 'Tables', 'market': 'Europe', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Furniture', 'subcat': 'Tables', 'market': 'LATAM', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Furniture', 'subcat': 'Tables', 'market': 'USCA', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Tables',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Furniture', 'subcat': 'Chairs', 'market': 'all', 'region': 'all'},
#  {'cat': 'Furniture', 'subcat': 'Chairs', 'market': 'Africa', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Furniture', 'subcat': 'Chairs', 'market': 'Europe', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Furniture', 'subcat': 'Chairs', 'market': 'LATAM', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Furniture', 'subcat': 'Chairs', 'market': 'USCA', 'region': 'all'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Furniture',
#   'subcat': 'Chairs',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies', 'subcat': 'all', 'market': 'all', 'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Appliances',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Binders',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Envelopes',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Fasteners',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Labels',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Paper',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Storage',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Supplies',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Office Supplies', 'subcat': 'Art', 'market': 'all', 'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Office Supplies',
#   'subcat': 'Art',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Technology', 'subcat': 'all', 'market': 'all', 'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'all',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Technology',
#   'subcat': 'Accessories',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Technology', 'subcat': 'Machines', 'market': 'all', 'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'USCA',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Technology',
#   'subcat': 'Machines',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Technology', 'subcat': 'Phones', 'market': 'all', 'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Technology', 'subcat': 'Phones', 'market': 'LATAM', 'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Technology', 'subcat': 'Phones', 'market': 'USCA', 'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Technology',
#   'subcat': 'Phones',
#   'market': 'USCA',
#   'region': 'Western US'},
#  {'cat': 'Technology', 'subcat': 'Copiers', 'market': 'all', 'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Africa',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Africa',
#   'region': 'Central Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Africa',
#   'region': 'Eastern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Africa',
#   'region': 'North Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Africa',
#   'region': 'Southern Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Africa',
#   'region': 'Western Africa'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Asia Pacific',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Asia Pacific',
#   'region': 'Central Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Asia Pacific',
#   'region': 'Eastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Asia Pacific',
#   'region': 'Oceania'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Asia Pacific',
#   'region': 'Southeastern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Asia Pacific',
#   'region': 'Southern Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Asia Pacific',
#   'region': 'Western Asia'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Europe',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Europe',
#   'region': 'Eastern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Europe',
#   'region': 'Northern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Europe',
#   'region': 'Southern Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'Europe',
#   'region': 'Western Europe'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'LATAM',
#   'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'LATAM',
#   'region': 'Caribbean'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'LATAM',
#   'region': 'Central America'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'LATAM',
#   'region': 'South America'},
#  {'cat': 'Technology', 'subcat': 'Copiers', 'market': 'USCA', 'region': 'all'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'USCA',
#   'region': 'Canada'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'USCA',
#   'region': 'Central US'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'USCA',
#   'region': 'Eastern US'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'USCA',
#   'region': 'Southern US'},
#  {'cat': 'Technology',
#   'subcat': 'Copiers',
#   'market': 'USCA',
#   'region': 'Western US'}]

# %%
def filterdata(df1,output='sales', cat = "all", subcat = "all", market = "all", region = "all" ):
    
    if cat != "all":
        df2 = df1[df1['cat']==cat]
    else:
        df2 = df1
    if subcat != "all":
        df3 = df2[df2['subcat']==subcat]
    else:
        df3 = df2
    if market != "all":
        df4 = df3[df3['market']==market]
    else:
        df4 = df3
    if region != "all":
        df5 = df4[df4['region']==region]
    else:
        df5 = df4
                
    df_filtered = df5.groupby(['date'], as_index = False)["{}".format(output)].sum()
    df_filtered = df_filtered.set_index('date').sort_values(by = 'date')

    return df_filtered


def to_integer(dt_time):
    return (dt_time.year-2016)*12 + dt_time.month

def clean_data(datapath, output='sales', cat = "all", subcat = "all", market = "all", region = "all"):
    df = pd.read_csv(datapath,encoding = "ISO-8859-1")
    df.drop(df.columns[[0,1,2,3,5,6,7,8,9,10,11,12,13,16,17,25]], axis=1, inplace=True)
    df.columns =['date',"region","market","subcat","cat","sales","quantity","discount","profit","shippingcost"]
    df['date'] = df['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))
    df['date'] = df['date'].apply(lambda dt: dt.replace(day=1))
    df_main = df.groupby(['date','region','market','subcat','cat'], as_index = False)['sales','profit','shippingcost'].sum()
    result_df = filterdata(df_main, output=output, cat =cat, subcat =subcat, market =market, region =region)
    return result_df

def forecast_period(year):
    fcst_date = []
    for year in np.arange(2020,year+1):
        for month in np.arange(1,13):
            fcst_date.append(dt.datetime(year,month,1))
    return fcst_date

def return_forecast(datapath, year = 2021, output='sales', cat = "all", subcat = "all", market = "all", region = "all"):

    result_df = clean_data(datapath, output=output, cat =cat, subcat =subcat, market =market, region =region)

    sum_2017 = result_df[result_df.index.year == 2017] .sum()
    sum_2018 = result_df[result_df.index.year == 2018] .sum()
    sum_2019 = result_df[result_df.index.year == 2019] .sum()

    growth_2018 =  sum_2018 / sum_2017
    growth_2019 =  sum_2018 / sum_2017

    Avg_growth = (growth_2018 + growth_2019)/2

    X_forecast = forecast_period(year)

    for row in X_forecast:
        result_df.loc[row] = result_df.iloc[-12] * Avg_growth

    df_diff = result_df.copy()

    df_diff['prev'] = df_diff[output].shift(1)
    df_diff['date'] = df_diff.index
    df_diff['diff'] = (df_diff[output] - df_diff['prev'])

    #create dataframe for transformation from time series to supervised
    df_supervised = df_diff.drop(['prev'],axis=1)
    #adding lags
    for inc in range(1,13):
        field_name = 'lag_' + str(inc)
        df_supervised[field_name] = df_supervised['diff'].shift(inc)

    #drop null values
    df_supervised = df_supervised.dropna().reset_index(drop=True)

    #import MinMaxScaler and create a new dataframe for LSTM model
    df_model = df_supervised.drop([output,'date'],axis=1)

    #split train and test set
    train_set, test_set = df_model[0:-(len(X_forecast)+12)].values, df_model[-(len(X_forecast)+12):].values

    #apply Min Max Scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_set)

    # reshape training set
    train_set = train_set.reshape(train_set.shape[0], train_set.shape[1])
    train_set_scaled = scaler.transform(train_set)

    # reshape test set
    test_set = test_set.reshape(test_set.shape[0], test_set.shape[1])
    test_set_scaled = scaler.transform(test_set)

    X_train, y_train = train_set_scaled[:, 1:], train_set_scaled[:, 0:1]
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test, y_test = test_set_scaled[:, 1:], test_set_scaled[:, 0:1]
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

    model = Sequential()
    model.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam', metrics=['mape'])
    model.fit(X_train, y_train, nb_epoch=200, batch_size=1, verbose=1, shuffle=False)
    accuracy = model.evaluate(X_test, y_test, batch_size = 1)

    y_pred = model.predict(X_test,batch_size=1)
    #for multistep prediction, you need to replace X_test values with the predictions coming from t-1

    #reshape y_pred
    y_pred = y_pred.reshape(y_pred.shape[0], 1, y_pred.shape[1])

    #rebuild test set for inverse transform
    pred_test_set = []
    for index in range(0,len(y_pred)):
        pred_test_set.append(np.concatenate([y_pred[index],X_test[index]],axis=1))

    pred_test_set = np.array(pred_test_set)
    pred_test_set = pred_test_set.reshape(pred_test_set.shape[0], pred_test_set.shape[2])
    pred_test_set_inverted = scaler.inverse_transform(pred_test_set)

    #create dataframe that shows the predicted sales
    result_list = []
    dates = list(result_df[-(len(X_forecast)+13):].index)
    act_value = list(result_df[-(len(X_forecast)+13):][output])

    for index in range(0,len(pred_test_set_inverted)):
        result_dict = {}
        result_dict['pred_value'] = int(pred_test_set_inverted[index][0] + act_value[index])
        result_dict['date'] = dates[index+1]
        result_list.append(result_dict)
    df_result = pd.DataFrame(result_list)
    #for multistep prediction, replace act_sales with the predicted sales

    #merge with actual sales dataframe
    df_sales_pred = pd.merge(result_df,df_result,on='date',how='left')
    df_sales_pred.iloc[-(len(X_forecast)):,1] = np.nan

    return df_sales_pred['date'], df_sales_pred[output], df_sales_pred['pred_value'], accuracy[0], accuracy[1]

# %%
x, y, y_pred, mse, mape = return_forecast(datapath, year = 2021, output='sales', cat = "all", subcat = "all", market = "all", region = "all")
plt.plot(x,y)
plt.plot(x,y_pred)
print('test loss, Mean Absolute Percentage Error(MAPE):', mse, mape)
# Out:
# Epoch 1/200
# 23/23 [==============================] - 0s 20ms/step - loss: 0.2884 - mape: 121.1413
# Epoch 2/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2704 - mape: 113.0497
# Epoch 3/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2596 - mape: 109.2497
# Epoch 4/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2507 - mape: 106.0787
# Epoch 5/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2433 - mape: 103.4490
# Epoch 6/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2369 - mape: 101.3006
# Epoch 7/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2311 - mape: 99.5809
# Epoch 8/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2257 - mape: 98.2448
# Epoch 9/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2205 - mape: 97.2434
# Epoch 10/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2155 - mape: 97.1608
# Epoch 11/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2106 - mape: 97.6432
# Epoch 12/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2056 - mape: 98.2029
# Epoch 13/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2006 - mape: 98.8184
# Epoch 14/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1956 - mape: 99.4705
# Epoch 15/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1906 - mape: 100.1428
# Epoch 16/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1855 - mape: 100.8217
# Epoch 17/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1803 - mape: 101.6286
# Epoch 18/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1752 - mape: 102.5954
# Epoch 19/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1702 - mape: 103.5434
# Epoch 20/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1651 - mape: 104.4639
# Epoch 21/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1602 - mape: 105.3482
# Epoch 22/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1554 - mape: 106.3454
# Epoch 23/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1507 - mape: 107.4206
# Epoch 24/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1462 - mape: 108.4224
# Epoch 25/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1417 - mape: 109.3391
# Epoch 26/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1375 - mape: 110.1589
# Epoch 27/200
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1334 - mape: 110.8704
# Epoch 28/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1294 - mape: 111.4631
# Epoch 29/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1256 - mape: 111.9272
# Epoch 30/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1219 - mape: 112.2545
# Epoch 31/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1183 - mape: 112.4384
# Epoch 32/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1148 - mape: 112.4737
# Epoch 33/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.